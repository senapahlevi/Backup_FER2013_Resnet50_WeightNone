# %%
import numpy as np
import pandas as pd
import os 
inputFolder = '/content/drive/MyDrive/Fer2013_backup/' 
for root, directories, filenames in os.walk(inputFolder): 
    for filename in filenames: print(os.path.join(root,filename))
# Out:
# /content/drive/MyDrive/Fer2013_backup/backUpfer2013.csv
# /content/drive/MyDrive/Fer2013_backup/checkpoint/best_model_resnet50_modelB2_170false.h5
# /content/drive/MyDrive/Fer2013_backup/checkpoint/best_model_resnet50_modelD2_170false.h5
# /content/drive/MyDrive/Fer2013_backup/checkpoint/Best_Model_resnet50Scracth_tipe7.h5
# /content/drive/MyDrive/Fer2013_backup/checkpoint/Best_Model_resnet50Scracth_tipe8.h5
# /content/drive/MyDrive/Fer2013_backup/checkpoint/Best_Model_resnet50Scracth_tipe9.h5

# %%
# %cd /content/drive/MyDrive/Fer2013_backup/
# Out:
# /content/drive/MyDrive/Fer2013_backup

# %%
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from tensorflow.keras.utils import plot_model


from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow
# %matplotlib inline

import keras.backend as K
K.set_image_data_format('channels_last')
K.set_learning_phase(1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:400: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '

# %%
#Define the identity block helper function.
def identity_block(X, f, filters, stage, block):
    """
    Implementation of the identity block
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    
    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value. You'll need this later to add back to the main path. 
    X_shortcut = X
    
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    
   
    # Second component of main path
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path 
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation 
    X = Add()([X_shortcut,X])
    X = Activation("relu")(X)
        
    return X

# %%
def convolutional_block(X, f, filters, stage, block, s = 2):
    """
    Implementation of the convolutional block4
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    s -- Integer, specifying the stride to be used
    
    Returns:
    X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path 
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a',padding = 'valid', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    
    # Second component of main path 
    X = Conv2D(F2, (f, f), strides = (1,1), name = conv_name_base + '2b',padding = 'same', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path 
    X = Conv2D(F3, (1, 1), strides = (1,1), name = conv_name_base + '2c',padding = 'valid', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    ##### SHORTCUT PATH #### 
    X_shortcut = Conv2D(F3, (1, 1), strides = (s,s), name = conv_name_base + '1',padding = 'valid', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation 
    X = Add()([X_shortcut,X])
    X = Activation("relu")(X)
        
    return X

# %%
"""def ResNet50(input_shape = (48,48,1), classes = 7):
    """
    Implementation of the popular ResNet50 the following architecture:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> TOPLAYER

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """
    
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    
    # Zero-Padding
    #X = ZeroPadding2D((1, 1))(X_input)
    X = X_input
    # Stage 1

    X = Conv2D(8, (3, 3), strides = (1, 1), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    # removed maxpool
    #X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [32, 32, 128], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [32, 32, 128], stage=2, block='b')
    X = identity_block(X, 3, [32, 32, 128], stage=2, block='c')


    # Stage 3 
    X = convolutional_block(X, f = 3, filters = [64,64,256], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [64,64,256], stage=3, block='b')
    X = identity_block(X, 3, [64,64,256], stage=3, block='c')
    X = identity_block(X, 3, [64,64,256], stage=3, block='d')

    # Stage 4 
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='d')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='e')
    X = identity_block(X, 3, [128, 128, 512], stage=4, block='f')

    # Stage 5 
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=5, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=5, block='c')

    # AVGPOOL . 
    X = AveragePooling2D((2,2), name='avg_pool')(X)
    
    # output layer
    X = Flatten()(X)
    X = Dense(512, activation = 'relu', name='fc1024' , kernel_initializer = glorot_uniform(seed=0))(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)
    
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name='ResNet50')

    return model"""

# %%
def ResNet50ori(input_shape = (48, 48, 1), classes = 7):
    """
    Implementation of the popular ResNet50 the following architecture:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> TOPLAYER

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """
    
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    
    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

    # Stage 3 (≈4 lines)
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    # Stage 4 (≈6 lines)
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    # Stage 5 (≈3 lines)
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    # AVGPOOL (≈1 line). Use "X = AveragePooling2D(...)(X)"
    X = AveragePooling2D((2,2), name="avg_pool")(X)
    
    # output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)
    
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name='ResNet50ori')

    return model

# %%
import cv2
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
import tensorflow as tf
 
dataset_path = '/content/drive/MyDrive/Fer2013_backup/backUpfer2013.csv'
image_size=(48,48)

def load_fer2013():
    data = pd.read_csv(dataset_path)
    data = (data[data['pixels'].notnull()])
    pixels = data['pixels'].tolist()
    width, height = 48, 48
    faces = []
    for pixel_sequence in pixels:
        face = [int(pixel) for pixel in pixel_sequence.split(' ')]
        face = np.asarray(face).reshape(width, height)
        face = cv2.resize(face.astype('uint8'),image_size)
        faces.append(face.astype('float32'))
    faces = np.asarray(faces)
    faces = np.expand_dims(faces, -1)
    emotions = (data['emotion'])#.values
    return faces, emotions
 
def preprocess_input(x, v2=True):
    x = x.astype('float32')
    x = x / 255.0
    if v2:
        x = x - 0.5
        x = x * 2.0
    return x
 
faces, emotions = load_fer2013()
faces = preprocess_input(faces)
#xtrain, xtest,ytrain,ytest = train_test_split(faces, emotions,test_size=0.2,shuffle=True)
#Data Augumentation
data_generator = ImageDataGenerator(
                        rotation_range=10,
                        shear_range = 10,
                        width_shift_range=0.1,
                        height_shift_range=0.1,
                        zoom_range=.1,
                        horizontal_flip=True)

# %%
xtrain, xtest, ytrain, ytest = train_test_split(faces, emotions, test_size=0.1, train_size=0.9)
x_train, x_val, y_train, y_val = train_test_split(xtrain, ytrain, test_size=0.1, train_size=0.9)

# %%
#hyperparameter and callback
batch_size = 64
num_epochs = 60
input_shape = (48, 48, 1)
num_classes = 7

# %%
#Compile the model.


from keras.optimizers import Adam, SGD
model = ResNet50ori(input_shape = (48, 48, 1), classes = 7)
optimizer = Adam(learning_rate=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-7)
model.compile(optimizer= optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
#kita mau save model callbacks
import os
try:
  os.mkdir('/content/drive/MyDrive/Fer2013_backup/scratchcheckpoint')
except:
  pass

# %%
file_name = 'Best_Model_resnet50oriScracth_tipe1.h5'

checkpoint_path = os.path.join('checkpoint',file_name)

# %%
call_back = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_path,
                                               monitor='val_accuracy',
                                               verbose=1,
                                               save_freq='epoch',
                                               save_best_only=True,
                                               save_weights_only=False,
                                               mode='max')

# %%
model.summary()
# Out:
# Model: "ResNet50ori"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 48, 48, 1)]  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 54, 54, 1)    0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 24, 24, 64)   3200        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 24, 24, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 24, 24, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 11, 11, 64)   0           activation_49[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 11, 11, 64)   4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 11, 11, 64)   256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 11, 11, 64)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 11, 11, 64)   36928       activation_50[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 11, 11, 64)   256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 11, 11, 64)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 11, 11, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 11, 11, 256)  16640       activation_51[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 11, 11, 256)  1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 11, 11, 256)  1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 11, 11, 256)  0           bn2a_branch1[0][0]
#                                                                  bn2a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 11, 11, 256)  0           add_16[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 11, 11, 64)   16448       activation_52[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 11, 11, 64)   256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 11, 11, 64)   0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 11, 11, 64)   36928       activation_53[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 11, 11, 64)   256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 11, 11, 64)   0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 11, 11, 256)  16640       activation_54[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 11, 11, 256)  1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 11, 11, 256)  0           activation_52[0][0]
#                                                                  bn2b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 11, 11, 256)  0           add_17[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 11, 11, 64)   16448       activation_55[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 11, 11, 64)   256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 11, 11, 64)   0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 11, 11, 64)   36928       activation_56[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 11, 11, 64)   256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 11, 11, 64)   0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 11, 11, 256)  16640       activation_57[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 11, 11, 256)  1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 11, 11, 256)  0           activation_55[0][0]
#                                                                  bn2c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 11, 11, 256)  0           add_18[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 6, 6, 128)    32896       activation_58[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 6, 6, 128)    512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 6, 6, 128)    0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 6, 6, 128)    147584      activation_59[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 6, 6, 128)    512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 6, 6, 128)    0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 6, 6, 512)    131584      activation_58[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 6, 6, 512)    66048       activation_60[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 6, 6, 512)    2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 6, 6, 512)    2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 6, 6, 512)    0           bn3a_branch1[0][0]
#                                                                  bn3a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 6, 6, 512)    0           add_19[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 6, 6, 128)    65664       activation_61[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 6, 6, 128)    512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 6, 6, 128)    0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 6, 6, 128)    147584      activation_62[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 6, 6, 128)    512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 6, 6, 128)    0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 6, 6, 512)    66048       activation_63[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 6, 6, 512)    2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 6, 6, 512)    0           activation_61[0][0]
#                                                                  bn3b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 6, 6, 512)    0           add_20[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 6, 6, 128)    65664       activation_64[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 6, 6, 128)    512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 6, 6, 128)    0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 6, 6, 128)    147584      activation_65[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 6, 6, 128)    512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 6, 6, 128)    0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 6, 6, 512)    66048       activation_66[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 6, 6, 512)    2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 6, 6, 512)    0           activation_64[0][0]
#                                                                  bn3c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 6, 6, 512)    0           add_21[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 6, 6, 128)    65664       activation_67[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 6, 6, 128)    512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 6, 6, 128)    0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 6, 6, 128)    147584      activation_68[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 6, 6, 128)    512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 6, 6, 128)    0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 6, 6, 512)    66048       activation_69[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 6, 6, 512)    2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 6, 6, 512)    0           activation_67[0][0]
#                                                                  bn3d_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 6, 6, 512)    0           add_22[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 3, 3, 256)    131328      activation_70[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 3, 3, 256)    0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_71[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 3, 3, 256)    0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 3, 3, 1024)   525312      activation_70[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_72[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 3, 3, 1024)   4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 3, 3, 1024)   0           bn4a_branch1[0][0]
#                                                                  bn4a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 3, 3, 1024)   0           add_23[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_73[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 3, 3, 256)    0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_74[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 3, 3, 256)    0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_75[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 3, 3, 1024)   0           activation_73[0][0]
#                                                                  bn4b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 3, 3, 1024)   0           add_24[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_76[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 3, 3, 256)    0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_77[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 3, 3, 256)    0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_78[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 3, 3, 1024)   0           activation_76[0][0]
#                                                                  bn4c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 3, 3, 1024)   0           add_25[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_79[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 3, 3, 256)    0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_80[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 3, 3, 256)    0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_81[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 3, 3, 1024)   0           activation_79[0][0]
#                                                                  bn4d_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 3, 3, 1024)   0           add_26[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_82[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 3, 3, 256)    0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_83[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 3, 3, 256)    0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_84[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 3, 3, 1024)   0           activation_82[0][0]
#                                                                  bn4e_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 3, 3, 1024)   0           add_27[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 3, 3, 256)    262400      activation_85[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 3, 3, 256)    1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 3, 3, 256)    0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 3, 3, 256)    590080      activation_86[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 3, 3, 256)    1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 3, 3, 256)    0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 3, 3, 1024)   263168      activation_87[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 3, 3, 1024)   4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 3, 3, 1024)   0           activation_85[0][0]
#                                                                  bn4f_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 3, 3, 1024)   0           add_28[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 2, 2, 512)    524800      activation_88[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 2, 2, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 2, 2, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 2, 2, 512)    2359808     activation_89[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 2, 2, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 2, 2, 2048)   2099200     activation_88[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_90[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 2, 2, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 2, 2, 2048)   0           bn5a_branch1[0][0]
#                                                                  bn5a_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 2, 2, 2048)   0           add_29[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 2, 2, 512)    1049088     activation_91[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 2, 2, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 2, 2, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 2, 2, 512)    2359808     activation_92[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 2, 2, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_93[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 2, 2, 2048)   0           activation_91[0][0]
#                                                                  bn5b_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 2, 2, 2048)   0           add_30[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 2, 2, 512)    1049088     activation_94[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 2, 2, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 2, 2, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 2, 2, 512)    2359808     activation_95[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 2, 2, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 2, 2, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 2, 2, 2048)   1050624     activation_96[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 2, 2, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 2, 2, 2048)   0           activation_94[0][0]
#                                                                  bn5c_branch2c[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 2, 2, 2048)   0           add_31[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 1, 1, 2048)   0           activation_97[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc7 (Dense)                     (None, 7)            14343       flatten_1[0][0]
# ==================================================================================================
# Total params: 23,595,783
# Trainable params: 23,542,663
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
"""history = model.fit(data_generator.flow(xtrain, ytrain,),
                        steps_per_epoch=len(xtrain) / batch_size,
                        epochs=num_epochs, verbose=1,callbacks=call_back,
                        validation_data= (xtest,ytest))"""
# Out:
# Epoch 1/50
# 448/448 [==============================] - 65s 122ms/step - loss: 2.2037 - accuracy: 0.2000 - val_loss: 1.8522 - val_accuracy: 0.2421
#
# Epoch 00001: val_accuracy improved from -inf to 0.24213, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/50
# 448/448 [==============================] - 51s 114ms/step - loss: 1.9323 - accuracy: 0.2191 - val_loss: 2.1617 - val_accuracy: 0.2207
#
# Epoch 00002: val_accuracy did not improve from 0.24213
# Epoch 3/50
# 448/448 [==============================] - 51s 115ms/step - loss: 1.8758 - accuracy: 0.2435 - val_loss: 2.0316 - val_accuracy: 0.2268
#
# Epoch 00003: val_accuracy did not improve from 0.24213
# Epoch 4/50
# 448/448 [==============================] - 51s 113ms/step - loss: 1.8396 - accuracy: 0.2415 - val_loss: 1.9659 - val_accuracy: 0.2403
#
# Epoch 00004: val_accuracy did not improve from 0.24213
# Epoch 5/50
# 448/448 [==============================] - 51s 115ms/step - loss: 1.8367 - accuracy: 0.2446 - val_loss: 1.9846 - val_accuracy: 0.2366
#
# Epoch 00005: val_accuracy did not improve from 0.24213
# Epoch 6/50
# 448/448 [==============================] - 56s 124ms/step - loss: 1.8225 - accuracy: 0.2417 - val_loss: 1.9875 - val_accuracy: 0.2434
#
# Epoch 00006: val_accuracy improved from 0.24213 to 0.24338, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 7/50
# 448/448 [==============================] - 56s 125ms/step - loss: 1.7984 - accuracy: 0.2575 - val_loss: 1.9273 - val_accuracy: 0.2601
#
# Epoch 00007: val_accuracy improved from 0.24338 to 0.26010, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 8/50
# 448/448 [==============================] - 51s 114ms/step - loss: 1.7929 - accuracy: 0.2571 - val_loss: 1.8984 - val_accuracy: 0.2502
#
# Epoch 00008: val_accuracy did not improve from 0.26010
# Epoch 9/50
# 448/448 [==============================] - 51s 114ms/step - loss: 1.7853 - accuracy: 0.2614 - val_loss: 1.8847 - val_accuracy: 0.2512
#
# Epoch 00009: val_accuracy did not improve from 0.26010
# Epoch 10/50
# 448/448 [==============================] - 51s 114ms/step - loss: 1.7824 - accuracy: 0.2696 - val_loss: 1.8467 - val_accuracy: 0.2637
#
# Epoch 00010: val_accuracy improved from 0.26010 to 0.26372, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 11/50
# 448/448 [==============================] - 56s 125ms/step - loss: 1.7648 - accuracy: 0.2770 - val_loss: 1.8403 - val_accuracy: 0.2740
#
# Epoch 00011: val_accuracy improved from 0.26372 to 0.27403, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 12/50
# 448/448 [==============================] - 51s 114ms/step - loss: 1.7604 - accuracy: 0.2836 - val_loss: 1.7919 - val_accuracy: 0.2813
#
# Epoch 00012: val_accuracy improved from 0.27403 to 0.28128, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 13/50
# 448/448 [==============================] - 56s 125ms/step - loss: 1.7526 - accuracy: 0.2837 - val_loss: 1.7943 - val_accuracy: 0.2867
#
# Epoch 00013: val_accuracy improved from 0.28128 to 0.28671, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 14/50
# 448/448 [==============================] - 51s 114ms/step - loss: 1.7442 - accuracy: 0.2862 - val_loss: 1.7921 - val_accuracy: 0.2867
#
# Epoch 00014: val_accuracy did not improve from 0.28671
# Epoch 15/50
# 448/448 [==============================] - 51s 114ms/step - loss: 1.7349 - accuracy: 0.3044 - val_loss: 1.7786 - val_accuracy: 0.3015
#
# Epoch 00015: val_accuracy improved from 0.28671 to 0.30148, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 16/50
# 448/448 [==============================] - 51s 114ms/step - loss: 1.7286 - accuracy: 0.3013 - val_loss: 1.7973 - val_accuracy: 0.2907
#
# Epoch 00016: val_accuracy did not improve from 0.30148
# Epoch 17/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.7191 - accuracy: 0.3055 - val_loss: 1.7580 - val_accuracy: 0.3012
#
# Epoch 00017: val_accuracy did not improve from 0.30148
# Epoch 18/50
# 448/448 [==============================] - 50s 111ms/step - loss: 1.7042 - accuracy: 0.3203 - val_loss: 1.7343 - val_accuracy: 0.3169
#
# Epoch 00018: val_accuracy improved from 0.30148 to 0.31694, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 19/50
# 448/448 [==============================] - 51s 113ms/step - loss: 1.7059 - accuracy: 0.3144 - val_loss: 1.7291 - val_accuracy: 0.3133
#
# Epoch 00019: val_accuracy did not improve from 0.31694
# Epoch 20/50
# 448/448 [==============================] - 55s 124ms/step - loss: 1.6789 - accuracy: 0.3315 - val_loss: 1.7038 - val_accuracy: 0.3292
#
# Epoch 00020: val_accuracy improved from 0.31694 to 0.32920, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 21/50
# 448/448 [==============================] - 51s 114ms/step - loss: 1.6888 - accuracy: 0.3214 - val_loss: 1.7362 - val_accuracy: 0.3242
#
# Epoch 00021: val_accuracy did not improve from 0.32920
# Epoch 22/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.6799 - accuracy: 0.3274 - val_loss: 1.7108 - val_accuracy: 0.3383
#
# Epoch 00022: val_accuracy improved from 0.32920 to 0.33826, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 23/50
# 448/448 [==============================] - 51s 113ms/step - loss: 1.6719 - accuracy: 0.3399 - val_loss: 1.6873 - val_accuracy: 0.3357
#
# Epoch 00023: val_accuracy did not improve from 0.33826
# Epoch 24/50
# 448/448 [==============================] - 51s 113ms/step - loss: 1.6615 - accuracy: 0.3390 - val_loss: 1.7021 - val_accuracy: 0.3366
#
# Epoch 00024: val_accuracy did not improve from 0.33826
# Epoch 25/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.6339 - accuracy: 0.3560 - val_loss: 1.7363 - val_accuracy: 0.3155
#
# Epoch 00025: val_accuracy did not improve from 0.33826
# Epoch 26/50
# 448/448 [==============================] - 50s 111ms/step - loss: 1.6421 - accuracy: 0.3476 - val_loss: 1.6750 - val_accuracy: 0.3423
#
# Epoch 00026: val_accuracy improved from 0.33826 to 0.34230, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 27/50
# 448/448 [==============================] - 50s 111ms/step - loss: 1.6272 - accuracy: 0.3605 - val_loss: 1.6422 - val_accuracy: 0.3640
#
# Epoch 00027: val_accuracy improved from 0.34230 to 0.36403, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 28/50
# 448/448 [==============================] - 50s 111ms/step - loss: 1.6160 - accuracy: 0.3723 - val_loss: 1.6246 - val_accuracy: 0.3663
#
# Epoch 00028: val_accuracy improved from 0.36403 to 0.36626, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 29/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.6172 - accuracy: 0.3617 - val_loss: 1.6089 - val_accuracy: 0.3741
#
# Epoch 00029: val_accuracy improved from 0.36626 to 0.37406, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 30/50
# 448/448 [==============================] - 51s 113ms/step - loss: 1.5968 - accuracy: 0.3776 - val_loss: 1.5940 - val_accuracy: 0.3770
#
# Epoch 00030: val_accuracy improved from 0.37406 to 0.37699, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 31/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.5946 - accuracy: 0.3780 - val_loss: 1.6182 - val_accuracy: 0.3658
#
# Epoch 00031: val_accuracy did not improve from 0.37699
# Epoch 32/50
# 448/448 [==============================] - 55s 121ms/step - loss: 1.5748 - accuracy: 0.3859 - val_loss: 1.6358 - val_accuracy: 0.3608
#
# Epoch 00032: val_accuracy did not improve from 0.37699
# Epoch 33/50
# 448/448 [==============================] - 50s 111ms/step - loss: 1.5793 - accuracy: 0.3804 - val_loss: 1.5892 - val_accuracy: 0.3848
#
# Epoch 00033: val_accuracy improved from 0.37699 to 0.38479, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 34/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.5550 - accuracy: 0.3955 - val_loss: 1.5574 - val_accuracy: 0.4016
#
# Epoch 00034: val_accuracy improved from 0.38479 to 0.40164, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 35/50
# 448/448 [==============================] - 55s 122ms/step - loss: 1.5469 - accuracy: 0.3924 - val_loss: 1.5700 - val_accuracy: 0.4004
#
# Epoch 00035: val_accuracy did not improve from 0.40164
# Epoch 36/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.5256 - accuracy: 0.4115 - val_loss: 1.5577 - val_accuracy: 0.3904
#
# Epoch 00036: val_accuracy did not improve from 0.40164
# Epoch 37/50
# 448/448 [==============================] - 51s 113ms/step - loss: 1.5384 - accuracy: 0.3979 - val_loss: 1.5474 - val_accuracy: 0.3980
#
# Epoch 00037: val_accuracy did not improve from 0.40164
# Epoch 38/50
# 448/448 [==============================] - 56s 124ms/step - loss: 1.5164 - accuracy: 0.4085 - val_loss: 1.5193 - val_accuracy: 0.4133
#
# Epoch 00038: val_accuracy improved from 0.40164 to 0.41335, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 39/50
# 448/448 [==============================] - 56s 124ms/step - loss: 1.5152 - accuracy: 0.4137 - val_loss: 1.5291 - val_accuracy: 0.4071
#
# Epoch 00039: val_accuracy did not improve from 0.41335
# Epoch 40/50
# 448/448 [==============================] - 51s 113ms/step - loss: 1.5017 - accuracy: 0.4225 - val_loss: 1.5037 - val_accuracy: 0.4153
#
# Epoch 00040: val_accuracy improved from 0.41335 to 0.41530, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 41/50
# 448/448 [==============================] - 56s 124ms/step - loss: 1.4817 - accuracy: 0.4263 - val_loss: 1.5207 - val_accuracy: 0.4089
#
# Epoch 00041: val_accuracy did not improve from 0.41530
# Epoch 42/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.4934 - accuracy: 0.4222 - val_loss: 1.4833 - val_accuracy: 0.4260
#
# Epoch 00042: val_accuracy improved from 0.41530 to 0.42602, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 43/50
# 448/448 [==============================] - 55s 122ms/step - loss: 1.4705 - accuracy: 0.4330 - val_loss: 1.5298 - val_accuracy: 0.4072
#
# Epoch 00043: val_accuracy did not improve from 0.42602
# Epoch 44/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.4537 - accuracy: 0.4402 - val_loss: 1.4667 - val_accuracy: 0.4330
#
# Epoch 00044: val_accuracy improved from 0.42602 to 0.43299, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 45/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.4580 - accuracy: 0.4343 - val_loss: 1.4737 - val_accuracy: 0.4288
#
# Epoch 00045: val_accuracy did not improve from 0.43299
# Epoch 46/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.4493 - accuracy: 0.4342 - val_loss: 1.5012 - val_accuracy: 0.4259
#
# Epoch 00046: val_accuracy did not improve from 0.43299
# Epoch 47/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.4309 - accuracy: 0.4492 - val_loss: 1.4657 - val_accuracy: 0.4344
#
# Epoch 00047: val_accuracy improved from 0.43299 to 0.43438, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 48/50
# 448/448 [==============================] - 50s 112ms/step - loss: 1.4289 - accuracy: 0.4413 - val_loss: 1.4330 - val_accuracy: 0.4409
#
# Epoch 00048: val_accuracy improved from 0.43438 to 0.44093, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 49/50
# 448/448 [==============================] - 51s 113ms/step - loss: 1.4104 - accuracy: 0.4547 - val_loss: 1.4492 - val_accuracy: 0.4413
#
# Epoch 00049: val_accuracy improved from 0.44093 to 0.44135, saving model to checkpoint/Best_Model_resnet50Scracth_tipe9.h5
# Epoch 50/50
# 448/448 [==============================] - 56s 124ms/step - loss: 1.4136 - accuracy: 0.4613 - val_loss: 1.5121 - val_accuracy: 0.4220
#
# Epoch 00050: val_accuracy did not improve from 0.44135

# %%
history = model.fit(
    data_generator.flow(xtrain, ytrain,),
    steps_per_epoch=len(xtrain) / batch_size,
    epochs=num_epochs, 
    verbose=1,
    callbacks=call_back,
    validation_data= (x_val,y_val))
# Out:
# Epoch 1/60
# 504/504 [==============================] - 88s 63ms/step - loss: 4.2246 - accuracy: 0.2260 - val_loss: 1.8114 - val_accuracy: 0.2632
#
# Epoch 00001: val_accuracy improved from -inf to 0.26316, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/60
# 504/504 [==============================] - 27s 54ms/step - loss: 1.7923 - accuracy: 0.2598 - val_loss: 1.7799 - val_accuracy: 0.2777
#
# Epoch 00002: val_accuracy improved from 0.26316 to 0.27771, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 3/60
# 504/504 [==============================] - 27s 53ms/step - loss: 1.7786 - accuracy: 0.2668 - val_loss: 1.7277 - val_accuracy: 0.3046
#
# Epoch 00003: val_accuracy improved from 0.27771 to 0.30464, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 4/60
# 504/504 [==============================] - 27s 53ms/step - loss: 1.7418 - accuracy: 0.2863 - val_loss: 1.7285 - val_accuracy: 0.3111
#
# Epoch 00004: val_accuracy improved from 0.30464 to 0.31115, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 5/60
# 504/504 [==============================] - 27s 54ms/step - loss: 1.7265 - accuracy: 0.2967 - val_loss: 1.7731 - val_accuracy: 0.3006
#
# Epoch 00005: val_accuracy did not improve from 0.31115
# Epoch 6/60
# 504/504 [==============================] - 27s 54ms/step - loss: 1.7133 - accuracy: 0.3040 - val_loss: 1.7402 - val_accuracy: 0.3409
#
# Epoch 00006: val_accuracy improved from 0.31115 to 0.34087, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 7/60
# 504/504 [==============================] - 27s 54ms/step - loss: 1.6959 - accuracy: 0.3051 - val_loss: 1.6324 - val_accuracy: 0.3678
#
# Epoch 00007: val_accuracy improved from 0.34087 to 0.36780, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 8/60
# 504/504 [==============================] - 27s 54ms/step - loss: 1.6389 - accuracy: 0.3483 - val_loss: 1.6145 - val_accuracy: 0.3752
#
# Epoch 00008: val_accuracy improved from 0.36780 to 0.37523, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 9/60
# 504/504 [==============================] - 27s 54ms/step - loss: 1.6376 - accuracy: 0.3470 - val_loss: 1.5702 - val_accuracy: 0.3820
#
# Epoch 00009: val_accuracy improved from 0.37523 to 0.38204, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 10/60
# 504/504 [==============================] - 27s 54ms/step - loss: 1.6052 - accuracy: 0.3614 - val_loss: 1.7554 - val_accuracy: 0.3954
#
# Epoch 00010: val_accuracy improved from 0.38204 to 0.39536, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 11/60
# 504/504 [==============================] - 28s 54ms/step - loss: 1.5639 - accuracy: 0.3898 - val_loss: 1.5844 - val_accuracy: 0.4257
#
# Epoch 00011: val_accuracy improved from 0.39536 to 0.42570, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 12/60
# 504/504 [==============================] - 29s 57ms/step - loss: 1.5142 - accuracy: 0.4101 - val_loss: 1.4456 - val_accuracy: 0.4375
#
# Epoch 00012: val_accuracy improved from 0.42570 to 0.43746, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 13/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.4657 - accuracy: 0.4347 - val_loss: 1.4023 - val_accuracy: 0.4514
#
# Epoch 00013: val_accuracy improved from 0.43746 to 0.45139, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 14/60
# 504/504 [==============================] - 29s 57ms/step - loss: 1.4415 - accuracy: 0.4425 - val_loss: 1.5402 - val_accuracy: 0.4372
#
# Epoch 00014: val_accuracy did not improve from 0.45139
# Epoch 15/60
# 504/504 [==============================] - 27s 54ms/step - loss: 1.4066 - accuracy: 0.4549 - val_loss: 1.5346 - val_accuracy: 0.4238
#
# Epoch 00015: val_accuracy did not improve from 0.45139
# Epoch 16/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.3963 - accuracy: 0.4673 - val_loss: 1.3238 - val_accuracy: 0.4981
#
# Epoch 00016: val_accuracy improved from 0.45139 to 0.49814, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 17/60
# 504/504 [==============================] - 29s 57ms/step - loss: 1.3673 - accuracy: 0.4756 - val_loss: 1.4197 - val_accuracy: 0.4560
#
# Epoch 00017: val_accuracy did not improve from 0.49814
# Epoch 18/60
# 504/504 [==============================] - 29s 57ms/step - loss: 1.3580 - accuracy: 0.4880 - val_loss: 1.3330 - val_accuracy: 0.4929
#
# Epoch 00018: val_accuracy did not improve from 0.49814
# Epoch 19/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.3366 - accuracy: 0.4889 - val_loss: 1.3132 - val_accuracy: 0.5025
#
# Epoch 00019: val_accuracy improved from 0.49814 to 0.50248, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 20/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.3192 - accuracy: 0.4975 - val_loss: 1.5977 - val_accuracy: 0.4536
#
# Epoch 00020: val_accuracy did not improve from 0.50248
# Epoch 21/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.3172 - accuracy: 0.4907 - val_loss: 1.3118 - val_accuracy: 0.5087
#
# Epoch 00021: val_accuracy improved from 0.50248 to 0.50867, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 22/60
# 504/504 [==============================] - 27s 54ms/step - loss: 1.3663 - accuracy: 0.4839 - val_loss: 6.4222 - val_accuracy: 0.3644
#
# Epoch 00022: val_accuracy did not improve from 0.50867
# Epoch 23/60
# 504/504 [==============================] - 29s 57ms/step - loss: 1.3816 - accuracy: 0.4682 - val_loss: 1.2374 - val_accuracy: 0.5322
#
# Epoch 00023: val_accuracy improved from 0.50867 to 0.53220, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 24/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.2956 - accuracy: 0.5005 - val_loss: 1.2303 - val_accuracy: 0.5322
#
# Epoch 00024: val_accuracy did not improve from 0.53220
# Epoch 25/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.2615 - accuracy: 0.5212 - val_loss: 1.2015 - val_accuracy: 0.5387
#
# Epoch 00025: val_accuracy improved from 0.53220 to 0.53870, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 26/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.2432 - accuracy: 0.5222 - val_loss: 1.2366 - val_accuracy: 0.5483
#
# Epoch 00026: val_accuracy improved from 0.53870 to 0.54830, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 27/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.2714 - accuracy: 0.5125 - val_loss: 1.2498 - val_accuracy: 0.5310
#
# Epoch 00027: val_accuracy did not improve from 0.54830
# Epoch 28/60
# 504/504 [==============================] - 29s 57ms/step - loss: 1.2370 - accuracy: 0.5292 - val_loss: 1.3623 - val_accuracy: 0.4963
#
# Epoch 00028: val_accuracy did not improve from 0.54830
# Epoch 29/60
# 504/504 [==============================] - 29s 57ms/step - loss: 1.2247 - accuracy: 0.5424 - val_loss: 1.2327 - val_accuracy: 0.5396
#
# Epoch 00029: val_accuracy did not improve from 0.54830
# Epoch 30/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.2322 - accuracy: 0.5290 - val_loss: 1.2139 - val_accuracy: 0.5412
#
# Epoch 00030: val_accuracy did not improve from 0.54830
# Epoch 31/60
# 504/504 [==============================] - 28s 54ms/step - loss: 1.2018 - accuracy: 0.5448 - val_loss: 1.1882 - val_accuracy: 0.5520
#
# Epoch 00031: val_accuracy improved from 0.54830 to 0.55201, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 32/60
# 504/504 [==============================] - 29s 57ms/step - loss: 1.2325 - accuracy: 0.5341 - val_loss: 1.1984 - val_accuracy: 0.5563
#
# Epoch 00032: val_accuracy improved from 0.55201 to 0.55635, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 33/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.2083 - accuracy: 0.5369 - val_loss: 1.1755 - val_accuracy: 0.5526
#
# Epoch 00033: val_accuracy did not improve from 0.55635
# Epoch 34/60
# 504/504 [==============================] - 27s 54ms/step - loss: 1.2279 - accuracy: 0.5432 - val_loss: 1.1782 - val_accuracy: 0.5734
#
# Epoch 00034: val_accuracy improved from 0.55635 to 0.57337, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 35/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.1937 - accuracy: 0.5474 - val_loss: 1.1280 - val_accuracy: 0.5675
#
# Epoch 00035: val_accuracy did not improve from 0.57337
# Epoch 36/60
# 504/504 [==============================] - 27s 54ms/step - loss: 1.1780 - accuracy: 0.5512 - val_loss: 1.1383 - val_accuracy: 0.5743
#
# Epoch 00036: val_accuracy improved from 0.57337 to 0.57430, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 37/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.1589 - accuracy: 0.5601 - val_loss: 1.1006 - val_accuracy: 0.5972
#
# Epoch 00037: val_accuracy improved from 0.57430 to 0.59721, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 38/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.1864 - accuracy: 0.5489 - val_loss: 1.1416 - val_accuracy: 0.5811
#
# Epoch 00038: val_accuracy did not improve from 0.59721
# Epoch 39/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.1560 - accuracy: 0.5638 - val_loss: 1.0867 - val_accuracy: 0.5978
#
# Epoch 00039: val_accuracy improved from 0.59721 to 0.59783, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 40/60
# 504/504 [==============================] - 29s 57ms/step - loss: 1.1479 - accuracy: 0.5644 - val_loss: 1.1207 - val_accuracy: 0.5786
#
# Epoch 00040: val_accuracy did not improve from 0.59783
# Epoch 41/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.1702 - accuracy: 0.5559 - val_loss: 1.0673 - val_accuracy: 0.6006
#
# Epoch 00041: val_accuracy improved from 0.59783 to 0.60062, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 42/60
# 504/504 [==============================] - 29s 57ms/step - loss: 1.1171 - accuracy: 0.5764 - val_loss: 1.0613 - val_accuracy: 0.5994
#
# Epoch 00042: val_accuracy did not improve from 0.60062
# Epoch 43/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.1377 - accuracy: 0.5724 - val_loss: 1.1087 - val_accuracy: 0.5923
#
# Epoch 00043: val_accuracy did not improve from 0.60062
# Epoch 44/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.1362 - accuracy: 0.5714 - val_loss: 1.0890 - val_accuracy: 0.5957
#
# Epoch 00044: val_accuracy did not improve from 0.60062
# Epoch 45/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.1077 - accuracy: 0.5844 - val_loss: 1.1494 - val_accuracy: 0.5684
#
# Epoch 00045: val_accuracy did not improve from 0.60062
# Epoch 46/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.2329 - accuracy: 0.5338 - val_loss: 1.2233 - val_accuracy: 0.5539
#
# Epoch 00046: val_accuracy did not improve from 0.60062
# Epoch 47/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.1809 - accuracy: 0.5536 - val_loss: 1.0845 - val_accuracy: 0.5957
#
# Epoch 00047: val_accuracy did not improve from 0.60062
# Epoch 48/60
# 504/504 [==============================] - 29s 57ms/step - loss: 1.1218 - accuracy: 0.5828 - val_loss: 1.1076 - val_accuracy: 0.5981
#
# Epoch 00048: val_accuracy did not improve from 0.60062
# Epoch 49/60
# 504/504 [==============================] - 27s 54ms/step - loss: 1.1475 - accuracy: 0.5686 - val_loss: 1.3476 - val_accuracy: 0.4904
#
# Epoch 00049: val_accuracy did not improve from 0.60062
# Epoch 50/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.1624 - accuracy: 0.5621 - val_loss: 1.0566 - val_accuracy: 0.6136
#
# Epoch 00050: val_accuracy improved from 0.60062 to 0.61362, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 51/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.1106 - accuracy: 0.5828 - val_loss: 1.0484 - val_accuracy: 0.6217
#
# Epoch 00051: val_accuracy improved from 0.61362 to 0.62167, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 52/60
# 504/504 [==============================] - 29s 57ms/step - loss: 1.1206 - accuracy: 0.5763 - val_loss: 1.2040 - val_accuracy: 0.5820
#
# Epoch 00052: val_accuracy did not improve from 0.62167
# Epoch 53/60
# 504/504 [==============================] - 28s 54ms/step - loss: 1.0966 - accuracy: 0.5826 - val_loss: 1.0986 - val_accuracy: 0.5820
#
# Epoch 00053: val_accuracy did not improve from 0.62167
# Epoch 54/60
# 504/504 [==============================] - 29s 57ms/step - loss: 1.1352 - accuracy: 0.5771 - val_loss: 1.1021 - val_accuracy: 0.6074
#
# Epoch 00054: val_accuracy did not improve from 0.62167
# Epoch 55/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.1096 - accuracy: 0.5871 - val_loss: 1.1193 - val_accuracy: 0.5910
#
# Epoch 00055: val_accuracy did not improve from 0.62167
# Epoch 56/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.0888 - accuracy: 0.5918 - val_loss: 1.0226 - val_accuracy: 0.6195
#
# Epoch 00056: val_accuracy did not improve from 0.62167
# Epoch 57/60
# 504/504 [==============================] - 29s 57ms/step - loss: 1.0713 - accuracy: 0.5929 - val_loss: 1.0452 - val_accuracy: 0.6254
#
# Epoch 00057: val_accuracy improved from 0.62167 to 0.62539, saving model to checkpoint/Best_Model_resnet50oriScracth_tipe1.h5
# Epoch 58/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.2515 - accuracy: 0.5390 - val_loss: 1.0841 - val_accuracy: 0.6053
#
# Epoch 00058: val_accuracy did not improve from 0.62539
# Epoch 59/60
# 504/504 [==============================] - 28s 55ms/step - loss: 1.1268 - accuracy: 0.5748 - val_loss: 1.2350 - val_accuracy: 0.6226
#
# Epoch 00059: val_accuracy did not improve from 0.62539
# Epoch 60/60
# 504/504 [==============================] - 28s 56ms/step - loss: 1.0710 - accuracy: 0.5960 - val_loss: 1.0972 - val_accuracy: 0.6108
#
# Epoch 00060: val_accuracy did not improve from 0.62539

# %%
import matplotlib.pyplot as plt 

#gffhgffkjkjdshufdf
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
num_epochs = range(len(accuracy))
plt.plot(num_epochs, accuracy, 'r', label='Training acc')
plt.plot(num_epochs, val_accuracy, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')  
plt.xlabel('epoch')
plt.legend()
plt.figure()
plt.plot(num_epochs, loss, 'r', label='Training loss')
plt.plot(num_epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.ylabel('loss')  
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
testloss = model.evaluate(xtest, ytest) 
print("Test Loss " + str(testloss[0]))
print("Test Acc: " + str(testloss[1]))
trainloss = model.evaluate(xtrain, ytrain) 
print("Train Loss " + str(trainloss[0]))
print("Train Acc: " + str(trainloss[1]))
# Out:
# 113/113 [==============================] - 2s 18ms/step - loss: 1.1740 - accuracy: 0.5659
# Test Loss 1.1740403175354004
# Test Acc: 0.5658957958221436
# 1010/1010 [==============================] - 15s 14ms/step - loss: 1.0868 - accuracy: 0.6079
# Train Loss 1.0867596864700317
# Train Acc: 0.607901394367218

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix
y_pred1 = model.predict(xtest)
y_pred = np.argmax(y_pred1, axis=1)

# Print f1, precision, and recall scores
print(precision_score(ytest, y_pred , average="macro"))
print(recall_score(ytest, y_pred , average="macro"))
print(f1_score(ytest, y_pred , average="macro"))
# Out:
# 0.5314742238598472
# 0.4998286207283074
# 0.5008222257040063
